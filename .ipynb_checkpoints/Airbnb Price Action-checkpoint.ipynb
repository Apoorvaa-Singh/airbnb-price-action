# %% [markdown]
# # Data Exploration
# #### Understanding the data better

# %%
# Importing the required libraries for the analysis

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading the csv file and creating a dataframe object 
airbnb = pd.read_csv("airbnb_price.csv")

# %%
# Review the imported data (top and bottom data)
airbnb.head()
# Out:
#     room_id  survey_id   host_id    room_type  country       city  borough  \
# 0  10176931       1476  49180562  Shared room      NaN  Amsterdam      NaN
# 1   8935871       1476  46718394  Shared room      NaN  Amsterdam      NaN
# 2  14011697       1476  10346595  Shared room      NaN  Amsterdam      NaN
# 3   6137978       1476   8685430  Shared room      NaN  Amsterdam      NaN
# 4  18630616       1476  70191803  Shared room      NaN  Amsterdam      NaN
#
#               neighborhood  reviews  overall_satisfaction  accommodates  \
# 0  De Pijp / Rivierenbuurt        7                   4.5             2
# 1             Centrum West       45                   4.5             4
# 2          Watergraafsmeer        1                   0.0             3
# 3             Centrum West        7                   5.0             4
# 4   De Baarsjes / Oud West        1                   0.0             2
#
#    bedrooms  bathrooms  price  minstay  \
# ...

# %%
airbnb.tail()
# Out:
#         room_id  survey_id    host_id     room_type  country       city  \
# 18718  17789893       1476   47501089  Private room      NaN  Amsterdam
# 18719  16877166       1476   67093870  Private room      NaN  Amsterdam
# 18720  19859427       1476   29724632  Private room      NaN  Amsterdam
# 18721  17132164       1476  115156569  Private room      NaN  Amsterdam
# 18722   7605782       1476   39503013  Private room      NaN  Amsterdam
#
#        borough             neighborhood  reviews  overall_satisfaction  \
# 18718      NaN          Bijlmer Centrum       10                   5.0
# 18719      NaN          Bijlmer Centrum        6                   5.0
# 18720      NaN  Geuzenveld / Slotermeer        0                   0.0
# 18721      NaN             Centrum West       13                   4.5
# 18722      NaN             Centrum West      113                   4.5
#
#        accommodates  bedrooms  bathrooms  price  minstay  \
# ...

# %%
# Check the Data Info
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18723 entries, 0 to 18722
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   room_id               18723 non-null  int64
#  1   survey_id             18723 non-null  int64
#  2   host_id               18723 non-null  int64
#  3   room_type             18723 non-null  object
#  4   country               0 non-null      float64
#  5   city                  18723 non-null  object
#  6   borough               0 non-null      float64
#  7   neighborhood          18723 non-null  object
#  8   reviews               18723 non-null  int64
#  9   overall_satisfaction  18723 non-null  float64
#  10  accommodates          18723 non-null  int64
#  11  bedrooms              18723 non-null  float64
#  12  bathrooms             0 non-null      float64
#  13  price                 18723 non-null  float64
#  14  minstay               0 non-null      float64
# ...

# %%
# Since columns country, borough, bathrooms and  minstay have no values in the them, removing them from the dataset. 
airbnb.drop(["country", "borough", "bathrooms", "minstay"],axis = 1, inplace  = True)

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18723 entries, 0 to 18722
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   room_id               18723 non-null  int64
#  1   survey_id             18723 non-null  int64
#  2   host_id               18723 non-null  int64
#  3   room_type             18723 non-null  object
#  4   city                  18723 non-null  object
#  5   neighborhood          18723 non-null  object
#  6   reviews               18723 non-null  int64
#  7   overall_satisfaction  18723 non-null  float64
#  8   accommodates          18723 non-null  int64
#  9   bedrooms              18723 non-null  float64
#  10  price                 18723 non-null  float64
#  11  name                  18671 non-null  object
#  12  last_modified         18723 non-null  object
#  13  latitude              18723 non-null  float64
#  14  longitude             18723 non-null  float64
# ...

# %%
# Describing the Dataset for overall summary, Selecting the relevant columns to desccribe from the entire dataset. 
airbnb[["reviews", "overall_satisfaction","accommodates","bedrooms", "price"]].describe()
# Out:
#             reviews  overall_satisfaction  accommodates      bedrooms  \
# count  18723.000000          18723.000000  18723.000000  18723.000000
# mean      16.741548              3.301127      2.922021      1.430380
# std       33.522630              2.213558      1.327524      0.879019
# min        0.000000              0.000000      1.000000      0.000000
# 25%        2.000000              0.000000      2.000000      1.000000
# 50%        6.000000              4.500000      2.000000      1.000000
# 75%       17.000000              5.000000      4.000000      2.000000
# max      532.000000              5.000000     17.000000     10.000000
#
#               price
# count  18723.000000
# mean     166.599477
# std      108.943849
# min       12.000000
# 25%      108.000000
# 50%      144.000000
# 75%      192.000000
# max     6000.000000

# %%
# What are the Various room types available (along with the count)
airbnb["room_type"].value_counts()
# Out:
# Entire home/apt    14978
# Private room        3682
# Shared room           63
# Name: room_type, dtype: int64

# %%
# Dropping the "Shared room type" as the count in the data is very low compared to others. 
airbnb = airbnb[airbnb["room_type"] != "Shared room"]

# %%
# Analysing how popular each neaighbourhood is with respect to airbnb apartment number. 
# These nhumbers tells us what is the most common neighborhood or where are the most rooms situated. We can do multiple analysis
#around this including - prefered locality, corelation between location and rating and reviews, rent and occupancy  
airbnb["neighborhood"].value_counts()
# Out:
# De Baarsjes / Oud West                    3280
# De Pijp / Rivierenbuurt                   2371
# Centrum West                              2217
# Centrum Oost                              1724
# Westerpark                                1424
# Noord-West / Noord-Midden                 1416
# Oud Oost                                  1167
# Bos en Lommer                              985
# Oostelijk Havengebied / Indische Buurt     916
# Watergraafsmeer                            515
# Oud Noord                                  492
# Ijburg / Eiland Zeeburg                    378
# Slotervaart                                346
# Buitenveldert / Zuidas                     248
# Noord West                                 241
# Noord Oost                                 221
# Geuzenveld / Slotermeer                    192
# Osdorp                                     161
# De Aker / Nieuw Sloten                     114
# Bijlmer Centrum                             98
# ...

# %%
# Number of properties againt each review. 
# Number of reviews for each property
airbnb["reviews"].value_counts()
# Out:
# 0      2975
# 1      1500
# 2      1238
# 3      1100
# 4       924
#        ...
# 390       1
# 166       1
# 323       1
# 201       1
# 188       1
# Name: reviews, Length: 283, dtype: int64

# %%
airbnb["overall_satisfaction"].value_counts()
# Out:
# 5.0    7697
# 0.0    5721
# 4.5    4543
# 4.0     573
# 3.5     105
# 3.0      19
# 2.5       1
# 1.0       1
# Name: overall_satisfaction, dtype: int64

# %%
#Finding those properties where overall_satisfaction is zero and exploring them
airbnb_0_satisfaction = airbnb[airbnb["overall_satisfaction"] == 0.0]

# %%
airbnb_0_satisfaction
# Out:
#         room_id  survey_id    host_id        room_type       city  \
# 34      3119298       1476   15847782  Entire home/apt  Amsterdam
# 36     10511291       1476    5421078  Entire home/apt  Amsterdam
# 37     18047871       1476    9302267  Entire home/apt  Amsterdam
# 38      7468232       1476    7215538  Entire home/apt  Amsterdam
# 40      5818567       1476   29561840  Entire home/apt  Amsterdam
# ...         ...        ...        ...              ...        ...
# 18708  16411584       1476   83673574     Private room  Amsterdam
# 18709  12886265       1476   50843183     Private room  Amsterdam
# 18714  19203256       1476  132265798     Private room  Amsterdam
# 18715  19734178       1476  139135665     Private room  Amsterdam
# 18720  19859427       1476   29724632     Private room  Amsterdam
#
#                                  neighborhood  reviews  overall_satisfaction  \
# 34                                 Westerpark        1                   0.0
# ...

# %%
airbnb_0_satisfaction.describe()
# This is to further explore why the rating was not given? Are there any common characteristics in the property. Particular price range
# Out:
#             room_id  survey_id       host_id      reviews  \
# count  5.721000e+03     5721.0  5.721000e+03  5721.000000
# mean   1.472219e+07     1476.0  4.674155e+07     0.700926
# std    5.209774e+06        0.0  4.424869e+07     0.814133
# min    2.542800e+04     1476.0  2.234000e+03     0.000000
# 25%    1.150164e+07     1476.0  9.749992e+06     0.000000
# 50%    1.643578e+07     1476.0  2.962380e+07     0.000000
# 75%    1.917347e+07     1476.0  7.652614e+07     1.000000
# max    2.000373e+07     1476.0  1.418319e+08     5.000000
#
#        overall_satisfaction  accommodates     bedrooms        price  \
# count                5721.0   5721.000000  5721.000000  5721.000000
# mean                    0.0      3.024821     1.554623   175.620696
# std                     0.0      1.352056     0.949345   140.020220
# min                     0.0      1.000000     0.000000    22.000000
# 25%                     0.0      2.000000     1.000000   114.000000
# ...

# %%
airbnb[["last_modified", "latitude","longitude"]].describe()
# Out:
#            latitude     longitude
# count  18660.000000  18660.000000
# mean      52.365261      4.888606
# std        0.015141      0.034530
# min       52.296200      4.763264
# 25%       52.355251      4.864372
# 50%       52.364624      4.885995
# 75%       52.374789      4.907502
# max       52.424980      5.027689

# %%
airbnb_0_satisfaction[["last_modified", "latitude","longitude"]].describe()
# Out:
#           latitude    longitude
# count  5721.000000  5721.000000
# mean     52.364361     4.889534
# std       0.015795     0.036742
# min      52.296200     4.771083
# 25%      52.353951     4.862918
# 50%      52.363567     4.886634
# 75%      52.374183     4.909861
# max      52.424980     5.013075

# %%
# Out:
# '2017-07-23 12:58:15.945759'

# %%
# Out:
# '2017-07-22 16:05:14.149610'

# %%
# Satisfaction Rating where a property can accomodate 3 people
airbnb[airbnb["accommodates"]==3]["overall_satisfaction"].value_counts()
# Out:
# 5.0    621
# 0.0    483
# 4.5    411
# 4.0     56
# 3.5      8
# 3.0      4
# Name: overall_satisfaction, dtype: int64

# %%
# Satisfaction Rating where bedroom is 2 
airbnb[airbnb["bedrooms"]==2]["overall_satisfaction"].value_counts()
# Out:
# 5.0    1787
# 0.0    1487
# 4.5    1033
# 4.0     127
# 3.5      16
# 3.0       6
# Name: overall_satisfaction, dtype: int64

# %%
# Satisfaction Rating Where price is between $150 & $180 (including both)
# Rating based on the price range
airbnb[(airbnb["price"]>= 150) & (airbnb["price"] <= 180)]["overall_satisfaction"].value_counts()
# Out:
# 5.0    1634
# 0.0    1169
# 4.5     881
# 4.0     104
# 3.5      12
# 3.0       4
# Name: overall_satisfaction, dtype: int64

# %%
# Based on above exploration, inserting overall satisfaction value of 4 where it is missing.
# Imputing the value 4 in overall satisfaction where the value is present as 0
airbnb["overall_satisfaction"].mask(airbnb["overall_satisfaction"] == 0.0, 4.0, inplace = True)

# %%
# Now we will look back at the overall satisfaction after imputing
airbnb["overall_satisfaction"].value_counts()
# Out:
# 5.0    7697
# 4.0    6294
# 4.5    4543
# 3.5     105
# 3.0      19
# 2.5       1
# 1.0       1
# Name: overall_satisfaction, dtype: int64

# %%
# Count of each accomodation value to understand where is the most availability.The properties with can accomodate 2 people are most available 
airbnb["accommodates"].value_counts()
# Out:
# 2     9996
# 4     5563
# 3     1583
# 6      475
# 5      470
# 1      355
# 8      105
# 7       52
# 16      18
# 10      16
# 12       9
# 9        8
# 14       6
# 11       2
# 13       1
# 17       1
# Name: accommodates, dtype: int64

# %%
# Most common price range for the properties. 
airbnb["price"].value_counts()
# Out:
# 119.0    1023
# 180.0     999
# 144.0     886
# 150.0     621
# 132.0     587
#          ...
# 435.0       1
# 339.0       1
# 337.0       1
# 369.0       1
# 28.0        1
# Name: price, Length: 419, dtype: int64

# %%
airbnb.bedrooms.value_counts()/airbnb.bedrooms.count()
# Out:
# 1.0     0.591533
# 2.0     0.238800
# 3.0     0.077385
# 0.0     0.061844
# 4.0     0.025348
# 5.0     0.003323
# 6.0     0.001018
# 10.0    0.000268
# 7.0     0.000214
# 8.0     0.000161
# 9.0     0.000107
# Name: bedrooms, dtype: float64

# %%
# Proportion of each bedroom values in overall bedroom.

# %%
#Dropping the Data where the Bedroom number is equal to 0

# %%
# Check the info again
# Describe the dataset again (Write your observation as well)
#Plot a histogram of reviews where bins are 20 and range is in between 0 to 100

# %%
#Plot a histogram of reviews where bins are 20 and range is in between 0 to 1000

# %%
# Plot a histogram of accomodates where the bins are 16

# %%
#Plot of a histrogram of overall satisfaction

# %%
# plot a histogram of overall satisfaction where price is greater than 100 and less than equal than 200

# %%
#plot a histogram of overall satisfaction where the price is less than 50

# %%
# Plot a histogram of overall satisfaction where the price is greater than 200

# %%
# Plot a histogram of overall satisfaction where the price is greater than 300

# %%
# is there a relationship between price and reviews (scatter chart)(positive/negative relation)

# %%
# relation between accomodation and price

# %%
# relation ship between price and overall satisfaction

# %%
#price and bedroom (reltionship)

# %%
# In which neighbourhood most of the accomodation is availble (plotting the count of neighbourhood)

# %%
# reove the data where the price is greater than 1500 (outlier)

# %%
# Import scikit learn for linear regression
#create a X paramter (independent variable) by taking the column reviews, overall satisfaction , accomodates and bedroom
# creat a Y paramter by taking price
# split the data into test and train - 30% for testing 
# initialise and fit the linear regression.
